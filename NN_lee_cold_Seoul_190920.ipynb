# %%
#Neural Network
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras.layers import Bidirectional, GlobalMaxPool1D

#evaluation metrics
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error # for regression

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import missingno as msno

df = pd.read_csv("C:/Users/KHJ/cold_heat/data/lee_nhis_cold_daily_regional.csv", engine='python')
tb_sido = pd.read_csv("C:/Users/KHJ/cold_heat/data/sido_code.csv", engine='python')

dict_sido = tb_sido.set_index('name')['code'].to_dict()

df.region =df.region.map(dict_sido)

# %% [markdown]
# ## 시도별 지역 코드 불러오기

# %%
dict_sido
# Out:
# {'강원': 32,
#  '경기': 31,
#  '경남': 38,
#  '경북': 37,
#  '광주': 24,
#  '대구': 22,
#  '대전': 25,
#  '부산': 21,
#  '서울': 11,
#  '울산': 26,
#  '인천': 23,
#  '전남': 36,
#  '전국': 0,
#  '전북': 35,
#  '제주': 39,
#  '충북': 33,
#  '충남': 34,
#  '세종': 50}

# %%
#서울
df = df[df.region == 11]

# %% [markdown]
# ## 일요일, 공휴일 제거

# %%
#요일 구하기
from datetime import date
def weekday(y,m,h):
    y = y.astype('int')
    m = m.astype('int')
    h = h.astype('int')
    
    return date(y,m,h).weekday()

# %%
df['weekday'] = df.apply(lambda x: weekday(x.kma_year, x.kma_month, x.kma_date), axis=1)
df = df[df.weekday!=6]
df = df.reset_index()
y = df.TOTAL
df.drop("index",1,inplace=True)

# %%
df = df.drop(df[(df.kma_month==12) & (df.kma_date==25)].index)
df = df.drop(df[(df.kma_month==1) & (df.kma_date==1)].index)
df = df.drop(df[(df.kma_month==3) & (df.kma_date==1)].index)
#(1,1) (3,1) (12,25) 공휴일 제거
#설날 지우기
df = df.drop(df[(df.kma_year==2003) & (df.kma_month==1) & (df.kma_date==31)].index)
df = df.drop(df[(df.kma_year==2003) & (df.kma_month==2) & (df.kma_date==1)].index)
#df = df.drop(df[(df.kma_year==12) & (df.kma_month==3) & (df.kma_date==1)].index)
df = df.drop(df[(df.kma_year==2004) & (df.kma_month==1) & (df.kma_date==21)].index)
df = df.drop(df[(df.kma_year==2004) & (df.kma_month==1) & (df.kma_date==22)].index)
df = df.drop(df[(df.kma_year==2004) & (df.kma_month==1) & (df.kma_date==23)].index)
df = df.drop(df[(df.kma_year==2005) & (df.kma_month==2) & (df.kma_date==8)].index)
df = df.drop(df[(df.kma_year==2005) & (df.kma_month==2) & (df.kma_date==9)].index)
df = df.drop(df[(df.kma_year==2005) & (df.kma_month==2) & (df.kma_date==10)].index)
df = df.drop(df[(df.kma_year==2006) & (df.kma_month==1) & (df.kma_date==28)].index)
df = df.drop(df[(df.kma_year==2006) & (df.kma_month==1) & (df.kma_date==30)].index)
df = df.drop(df[(df.kma_year==2007) & (df.kma_month==1) & (df.kma_date==17)].index)
df = df.drop(df[(df.kma_year==2007) & (df.kma_month==1) & (df.kma_date==19)].index)
df = df.drop(df[(df.kma_year==2008) & (df.kma_month==2) & (df.kma_date==6)].index)
df = df.drop(df[(df.kma_year==2008) & (df.kma_month==2) & (df.kma_date==7)].index)
df = df.drop(df[(df.kma_year==2008) & (df.kma_month==2) & (df.kma_date==8)].index)
df = df.drop(df[(df.kma_year==2009) & (df.kma_month==1) & (df.kma_date==26)].index)
df = df.drop(df[(df.kma_year==2009) & (df.kma_month==1) & (df.kma_date==27)].index)
df = df.drop(df[(df.kma_year==2010) & (df.kma_month==2) & (df.kma_date==13)].index)
df = df.drop(df[(df.kma_year==2010) & (df.kma_month==2) & (df.kma_date==15)].index)
df = df.drop(df[(df.kma_year==2011) & (df.kma_month==2) & (df.kma_date==2)].index)
df = df.drop(df[(df.kma_year==2011) & (df.kma_month==2) & (df.kma_date==3)].index)
df = df.drop(df[(df.kma_year==2011) & (df.kma_month==2) & (df.kma_date==4)].index)
df = df.drop(df[(df.kma_year==2012) & (df.kma_month==1) & (df.kma_date==23)].index)
df = df.drop(df[(df.kma_year==2012) & (df.kma_month==1) & (df.kma_date==24)].index)
df = df.drop(df[(df.kma_year==2013) & (df.kma_month==2) & (df.kma_date==9)].index)
df = df.drop(df[(df.kma_year==2013) & (df.kma_month==2) & (df.kma_date==11)].index)
df = df.drop(df[(df.kma_year==2014) & (df.kma_month==1) & (df.kma_date==30)].index)
df = df.drop(df[(df.kma_year==2014) & (df.kma_month==1) & (df.kma_date==31)].index)
df = df.drop(df[(df.kma_year==2014) & (df.kma_month==2) & (df.kma_date==1)].index)
df = df.drop(df[(df.kma_year==2015) & (df.kma_month==2) & (df.kma_date==18)].index)
df = df.drop(df[(df.kma_year==2015) & (df.kma_month==2) & (df.kma_date==19)].index)
df = df.drop(df[(df.kma_year==2015) & (df.kma_month==2) & (df.kma_date==20)].index)
df = df.drop(df[(df.kma_year==2016) & (df.kma_month==2) & (df.kma_date==8)].index)
df = df.drop(df[(df.kma_year==2016) & (df.kma_month==2) & (df.kma_date==9)].index)
df = df.drop(df[(df.kma_year==2016) & (df.kma_month==2) & (df.kma_date==10)].index)
df = df.drop(df[(df.kma_year==2017) & (df.kma_month==1) & (df.kma_date==27)].index)
df = df.drop(df[(df.kma_year==2017) & (df.kma_month==1) & (df.kma_date==28)].index)
df = df.drop(df[(df.kma_year==2017) & (df.kma_month==1) & (df.kma_date==30)].index)

# %%
df = df.reset_index()
y = df.TOTAL
df.drop("TOTAL",1,inplace=True)
df.drop("index",1,inplace=True)

# %% [markdown]
# ## 데이터 구간별 나누기

# %%
df[1123:1496]
# Out:
#       kma_year  kma_month  kma_date  region  lo_kma_id  lag1_lo_kma_id  \
# 1123      2012          1         2      11       -8.3            -6.9
# 1124      2012          1         3      11       -6.8            -8.3
# 1125      2012          1         4      11       -9.6            -6.8
# 1126      2012          1         5      11       -9.8            -9.6
# 1127      2012          1         6      11       -5.6            -9.8
# 1128      2012          1         7      11       -8.0            -5.6
# 1129      2012          1         9      11       -1.8            -5.5
# 1130      2012          1        10      11       -5.8            -1.8
# 1131      2012          1        11      11       -8.1            -5.8
# 1132      2012          1        12      11      -10.3            -8.1
# 1133      2012          1        13      11       -4.1           -10.3
# 1134      2012          1        14      11       -6.3            -4.1
# 1135      2012          1        16      11       -5.1            -4.7
# 1136      2012          1        17      11        0.0            -5.1
# 1137      2012          1        18      11       -2.2             0.0
# 1138      2012          1        19      11        1.4            -2.2
# 1139      2012          1        20      11        3.7             1.4
# 1140      2012          1        21      11       -2.6             3.7
# 1141      2012          1        25      11      -11.6           -11.8
# 1142      2012          1        26      11       -8.5           -11.6
# 1143      2012          1        27      11       -4.4            -8.5
# 1144      2012          1        28      11       -6.0            -4.4
# 1145      2012          1        30      11       -8.8            -5.5
# 1146      2012          1        31      11       -8.5            -8.8
# 1147      2012          2         1      11      -15.3            -8.5
# 1148      2012          2         2      11      -17.1           -15.3
# 1149      2012          2         3      11      -14.5           -17.1
# 1150      2012          2         4      11       -5.2           -14.5
# 1151      2012          2         6      11       -3.2            -4.5
# 1152      2012          2         7      11      -11.5            -3.2
# ...        ...        ...       ...     ...        ...             ...
# 1466      2014         11        26      11        8.2             6.6
# 1467      2014         11        27      11        6.7             8.2
# 1468      2014         11        28      11        6.5             6.7
# 1469      2014         11        29      11        5.5             6.5
# 1470      2014         12         1      11       -7.2             7.2
# 1471      2014         12         2      11       -8.2            -7.2
# 1472      2014         12         3      11       -6.5            -8.2
# 1473      2014         12         4      11       -7.4            -6.5
# 1474      2014         12         5      11      -10.1            -7.4
# 1475      2014         12         6      11       -8.8           -10.1
# 1476      2014         12         8      11       -4.8            -8.2
# 1477      2014         12         9      11       -7.4            -4.8
# 1478      2014         12        10      11       -1.9            -7.4
# 1479      2014         12        11      11       -5.2            -1.9
# 1480      2014         12        12      11       -7.0            -5.2
# 1481      2014         12        13      11       -7.3            -7.0
# 1482      2014         12        15      11       -1.7            -8.6
# 1483      2014         12        16      11       -9.4            -1.7
# 1484      2014         12        17      11      -11.1            -9.4
# 1485      2014         12        18      11      -13.2           -11.1
# 1486      2014         12        19      11       -8.1           -13.2
# 1487      2014         12        20      11       -6.6            -8.1
# 1488      2014         12        22      11       -9.7            -9.0
# 1489      2014         12        23      11       -5.7            -9.7
# 1490      2014         12        24      11       -3.1            -5.7
# 1491      2014         12        26      11       -7.4            -5.9
# 1492      2014         12        27      11       -6.3            -7.4
# 1493      2014         12        29      11       -0.5            -3.6
# 1494      2014         12        30      11       -1.6            -0.5
# 1495      2014         12        31      11       -6.9            -1.6
#
#       lag2_lo_kma_id  lag3_lo_kma_id  hilo_kma_id  lag1_hilo_kma_id   ...     \
# 1123            -6.0            -6.4          7.1               7.3   ...
# 1124            -6.9            -6.0          6.6               7.1   ...
# 1125            -8.3            -6.9          5.3               6.6   ...
# 1126            -6.8            -8.3          8.5               5.3   ...
# 1127            -9.6            -6.8          6.9               8.5   ...
# 1128            -9.8            -9.6         10.0               6.9   ...
# 1129            -8.0            -5.6          4.5               5.9   ...
# 1130            -5.5            -8.0          7.3               4.5   ...
# 1131            -1.8            -5.5          4.8               7.3   ...
# 1132            -5.8            -1.8          9.9               4.8   ...
# 1133            -8.1            -5.8          6.7               9.9   ...
# 1134           -10.3            -8.1          9.0               6.7   ...
# 1135            -6.3            -4.1         12.9               5.0   ...
# 1136            -4.7            -6.3          8.2              12.9   ...
# 1137            -5.1            -4.7          7.6               8.2   ...
# 1138             0.0            -5.1          7.0               7.6   ...
# 1139            -2.2             0.0          4.6               7.0   ...
# 1140             1.4            -2.2          8.3               4.6   ...
# 1141           -12.2           -11.6          6.6               8.7   ...
# 1142           -11.8           -12.2         10.3               6.6   ...
# 1143           -11.6           -11.8          9.3              10.3   ...
# 1144            -8.5           -11.6          9.1               9.3   ...
# 1145            -6.0            -4.4          8.0               7.1   ...
# 1146            -5.5            -6.0          8.2               8.0   ...
# 1147            -8.8            -5.5          7.2               8.2   ...
# 1148            -8.5            -8.8          7.6               7.2   ...
# 1149           -15.3            -8.5         10.6               7.6   ...
# 1150           -17.1           -15.3          6.2              10.6   ...
# 1151            -5.2           -14.5         10.2               9.3   ...
# 1152            -4.5            -5.2         11.4              10.2   ...
# ...              ...             ...          ...               ...   ...
# 1466             8.0             6.3          8.1               8.5   ...
# 1467             6.6             8.0          8.2               8.1   ...
# 1468             8.2             6.6          3.6               8.2   ...
# 1469             6.7             8.2          7.3               3.6   ...
# 1470             5.5             6.5         15.1               3.9   ...
# 1471             7.2             5.5          5.5              15.1   ...
# 1472            -7.2             7.2          6.0               5.5   ...
# 1473            -8.2            -7.2          7.2               6.0   ...
# 1474            -6.5            -8.2          7.6               7.2   ...
# 1475            -7.4            -6.5          8.3               7.6   ...
# 1476            -8.8           -10.1          7.5               8.4   ...
# 1477            -8.2            -8.8         11.5               7.5   ...
# 1478            -4.8            -8.2          6.1              11.5   ...
# 1479            -7.4            -4.8          8.4               6.1   ...
# 1480            -1.9            -7.4          7.5               8.4   ...
# 1481            -5.2            -1.9          5.3               7.5   ...
# 1482            -7.3            -7.0          3.7               9.2   ...
# 1483            -8.6            -7.3         11.1               3.7   ...
# 1484            -1.7            -8.6          5.9              11.1   ...
# 1485            -9.4            -1.7         11.0               5.9   ...
# 1486           -11.1            -9.4          8.1              11.0   ...
# 1487           -13.2           -11.1          8.7               8.1   ...
# 1488            -6.6            -8.1         10.5               7.7   ...
# 1489            -9.0            -6.6          7.5              10.5   ...
# 1490            -9.7            -9.0          9.5               7.5   ...
# 1491            -3.1            -5.7          9.9               7.7   ...
# 1492            -5.9            -3.1         11.3               9.9   ...
# 1493            -6.3            -7.4          6.9               5.2   ...
# 1494            -3.6            -6.3          7.9               6.9   ...
# 1495            -0.5            -3.6          8.6               7.9   ...
#
#       lag3_hilo_kma_id  wimax_kma_id  lag1_wimax_kma_id  lag2_wimax_kma_id  \
# 1123               8.3           4.6                7.0                3.5
# 1124               7.4           5.8                4.6                7.0
# 1125               7.3           5.3                5.8                4.6
# 1126               7.1           3.8                5.3                5.8
# 1127               6.6           5.0                3.8                5.3
# 1128               5.3           3.2                5.0                3.8
# 1129               6.9           4.5                4.6                3.2
# 1130              10.0           4.8                4.5                4.6
# 1131               5.9           6.1                4.8                4.5
# 1132               4.5           6.3                6.1                4.8
# 1133               7.3           6.1                6.3                6.1
# 1134               4.8           5.5                6.1                6.3
# 1135               6.7           3.6                4.2                5.5
# 1136               9.0           4.5                3.6                4.2
# 1137               5.0           3.9                4.5                3.6
# 1138              12.9           6.6                3.9                4.5
# 1139               8.2           5.3                6.6                3.9
# 1140               7.6           5.9                5.3                6.6
# 1141               9.2           6.1                5.4                6.3
# 1142               6.9           6.4                6.1                5.4
# 1143               8.7           4.8                6.4                6.1
# 1144               6.6           4.7                4.8                6.4
# 1145               9.3           6.1                5.3                4.7
# 1146               9.1           7.5                6.1                5.3
# 1147               7.1           6.0                7.5                6.1
# 1148               8.0           5.9                6.0                7.5
# 1149               8.2           4.7                5.9                6.0
# 1150               7.2           5.6                4.7                5.9
# 1151              10.6           5.2                3.2                5.6
# 1152               6.2           7.6                5.2                3.2
# ...                ...           ...                ...                ...
# 1466               6.0           5.9                8.1                3.1
# 1467               5.2           3.2                5.9                8.1
# 1468               8.5           6.6                3.2                5.9
# 1469               8.1           4.5                6.6                3.2
# 1470               3.6          11.1                4.9                4.5
# 1471               7.3           7.1               11.1                4.9
# 1472               3.9           4.0                7.1               11.1
# 1473              15.1           5.9                4.0                7.1
# 1474               5.5           6.7                5.9                4.0
# 1475               6.0           6.6                6.7                5.9
# 1476               7.6           5.4                3.8                6.6
# 1477               8.3           4.2                5.4                3.8
# 1478               8.4           4.0                4.2                5.4
# 1479               7.5           7.0                4.0                4.2
# 1480              11.5           3.6                7.0                4.0
# 1481               6.1           6.8                3.6                7.0
# 1482               7.5           5.0                3.3                6.8
# 1483               5.3           8.4                5.0                3.3
# 1484               9.2           9.3                8.4                5.0
# 1485               3.7           4.8                9.3                8.4
# 1486              11.1           5.6                4.8                9.3
# 1487               5.9           7.4                5.6                4.8
# 1488               8.1           5.4                5.5                7.4
# 1489               8.7           4.1                5.4                5.5
# 1490               7.7           6.8                4.1                5.4
# 1491               7.5           4.5                5.5                6.8
# 1492               9.5           3.3                4.5                5.5
# 1493               9.9           4.8                3.5                3.3
# 1494              11.3           5.4                4.8                3.5
# 1495               5.2           9.2                5.4                4.8
#
#       lag3_wimax_kma_id  mt_lag1  lo_lag1  cold_warn0  cold_notice0  weekday
# 1123                4.1     -1.8     -1.4           0             0        0
# 1124                3.5      0.3      1.5           0             0        1
# 1125                7.0     -2.9     -2.8           0             0        2
# 1126                4.6      1.7     -0.2           0             0        3
# 1127                5.8      2.9      4.2           0             0        4
# 1128                5.3     -1.0     -2.4           0             0        5
# 1129                5.0      2.2      3.7           0             0        0
# 1130                3.2     -2.2     -4.0           0             0        1
# 1131                4.6     -3.5     -2.3           0             0        2
# 1132                4.5      1.4     -2.2           0             0        3
# 1133                4.8      3.4      6.2           0             0        4
# 1134                6.1     -0.3     -2.2           0             0        5
# 1135                6.1      3.6     -0.4           0             0        0
# 1136                5.5      1.8      5.1           0             0        1
# 1137                4.2     -1.4     -2.2           0             0        2
# 1138                3.6      3.9      3.6           0             0        3
# 1139                4.5      0.1      2.3           0             0        4
# 1140                3.9     -3.0     -6.3           0             0        5
# 1141                6.4     -0.9      0.2           0             1        2
# 1142                6.3      5.3      3.1           0             0        3
# 1143                5.4      2.0      4.1           0             0        4
# 1144                6.1     -0.9     -1.6           0             0        5
# 1145                4.8     -2.8     -3.3           0             0        0
# 1146                4.7      0.9      0.3           0             1        1
# 1147                5.3     -8.1     -6.8           0             1        2
# 1148                6.1     -0.9     -1.8           0             1        3
# 1149                7.5      5.1      2.6           0             1        4
# 1150                6.0      5.6      9.3           0             0        5
# 1151                4.7      1.8      1.3           0             0        0
# 1152                5.6     -9.6     -8.3           0             0        1
# ...                 ...      ...      ...         ...           ...      ...
# 1466                4.4      0.8      1.6           0             0        2
# 1467                3.1     -0.6     -1.5           0             0        3
# 1468                8.1     -1.6     -0.2           0             0        4
# 1469                5.9     -0.5     -1.0           0             0        5
# 1470                6.6    -10.2    -14.4           0             1        0
# 1471                4.5     -4.3     -1.0           0             1        1
# 1472                4.9      2.1      1.7           0             0        2
# 1473               11.1     -1.3     -0.9           0             0        3
# 1474                7.1     -2.0     -2.7           0             0        4
# 1475                4.0      1.0      1.3           0             0        5
# 1476                6.7      1.8      3.4           0             0        0
# 1477                6.6     -0.8     -2.6           0             0        1
# 1478                3.8      4.0      5.5           0             0        2
# 1479                5.4     -3.1     -3.3           0             0        3
# 1480                4.2     -2.3     -1.8           0             0        4
# 1481                4.0     -1.4     -0.3           0             0        5
# 1482                3.6      3.5      6.9           0             0        0
# 1483                6.8     -4.8     -7.7           0             1        1
# 1484                3.3     -4.1     -1.7           0             1        2
# 1485                5.0      0.7     -2.1           0             1        3
# 1486                8.4      4.5      5.1           0             0        4
# 1487                9.3      2.1      1.5           0             0        5
# 1488                5.6      1.7     -0.7           0             0        0
# 1489                7.4      3.4      4.0           0             0        1
# 1490                5.5      3.0      2.6           0             0        2
# 1491                4.1     -0.6     -1.5           0             0        4
# 1492                6.8      1.4      1.1           0             0        5
# 1493                4.5      3.7      3.1           0             0        0
# 1494                3.3     -1.0     -1.1           0             0        1
# 1495                3.5     -3.8     -5.3           0             0        2
#
# [373 rows x 21 columns]

# %%
df_drop = df.drop(['kma_year','kma_month','kma_date','region','cold_warn0','cold_notice0','weekday'],1)

# %%
#3Set 일 때
X_train = df_drop[2:1123]
X_valid = df_drop[1123:1496]
X_test = df_drop[1496:]
y_train = y[2:1123]
y_valid = y[1123:1496]
y_test = y[1496:]

# %% [markdown]
# ## 데이터 분포 시각화

# %%
import seaborn as sns #여러 가지 그림 그릴 수 있다
import matplotlib.pylab as plt 
fig,axes = plt.subplots(2,1, figsize=(20,12))
sns.distplot(y,ax=axes[0])
sns.distplot(np.log1p(y),ax=axes[1])
# Out:
# C:\Users\KHJ\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Neural Network 모델 학습

# %%
# import BatchNormalization
from keras.layers.normalization import BatchNormalization
model = Sequential()
#model.add(LSTM(24, input_shape=(14,1), kernel_initializer='normal', activation='relu'))
model.add(Dense(20, input_dim=14, kernel_initializer='normal', activation='relu')) # (timestep, feature)
model.add(Dropout(0.01))
#model.add(Dense(16, activation='relu'))
#model.add(Dropout(0.02))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.01))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 20)                300
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 168
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 477
# Trainable params: 477
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_array = np.asarray(X_train)
X_valid_array = np.asarray(X_valid)
X_test_array = np.asarray(X_test)

# %%
X_train2 = np.reshape(X_train_array, (X_train.shape[0],  X_train.shape[1],1))
X_valid2 = np.reshape(X_valid_array, (X_valid.shape[0],  X_valid.shape[1],1))
X_test2 = np.reshape(X_test_array, (X_test.shape[0],  X_test.shape[1],1))

# %%
model.compile(loss='mse', optimizer=Adam(lr=1e-4), metrics=['mse','mae'])

# %%
history = model.fit(X_train, y_train, epochs=150, batch_size=50,  verbose=1, validation_split=0.2)
# Out:
# Train on 896 samples, validate on 225 samples
# Epoch 1/150
# 896/896 [==============================] - 0s 506us/step - loss: 599.0149 - mean_squared_error: 599.0149 - mean_absolute_error: 14.4347 - val_loss: 5309.2755 - val_mean_squared_error: 5309.2755 - val_mean_absolute_error: 44.1057
# Epoch 2/150
# 896/896 [==============================] - 0s 30us/step - loss: 591.0476 - mean_squared_error: 591.0476 - mean_absolute_error: 14.1963 - val_loss: 5282.5582 - val_mean_squared_error: 5282.5582 - val_mean_absolute_error: 43.8471
# Epoch 3/150
# 896/896 [==============================] - 0s 24us/step - loss: 582.7674 - mean_squared_error: 582.7674 - mean_absolute_error: 13.9457 - val_loss: 5254.4021 - val_mean_squared_error: 5254.4021 - val_mean_absolute_error: 43.5800
# Epoch 4/150
# 896/896 [==============================] - 0s 27us/step - loss: 574.5406 - mean_squared_error: 574.5406 - mean_absolute_error: 13.6928 - val_loss: 5223.5460 - val_mean_squared_error: 5223.5460 - val_mean_absolute_error: 43.2921
# Epoch 5/150
# 896/896 [==============================] - 0s 26us/step - loss: 565.7278 - mean_squared_error: 565.7278 - mean_absolute_error: 13.4190 - val_loss: 5193.1697 - val_mean_squared_error: 5193.1697 - val_mean_absolute_error: 42.9992
# Epoch 6/150
# 896/896 [==============================] - 0s 45us/step - loss: 556.4916 - mean_squared_error: 556.4916 - mean_absolute_error: 13.1580 - val_loss: 5160.7352 - val_mean_squared_error: 5160.7352 - val_mean_absolute_error: 42.6858
# Epoch 7/150
# 896/896 [==============================] - 0s 27us/step - loss: 547.7137 - mean_squared_error: 547.7137 - mean_absolute_error: 12.8818 - val_loss: 5126.1138 - val_mean_squared_error: 5126.1138 - val_mean_absolute_error: 42.3517
# Epoch 8/150
# 896/896 [==============================] - 0s 31us/step - loss: 537.6357 - mean_squared_error: 537.6357 - mean_absolute_error: 12.5925 - val_loss: 5090.8882 - val_mean_squared_error: 5090.8882 - val_mean_absolute_error: 42.0092
# Epoch 9/150
# 896/896 [==============================] - 0s 23us/step - loss: 527.9243 - mean_squared_error: 527.9243 - mean_absolute_error: 12.2933 - val_loss: 5053.7772 - val_mean_squared_error: 5053.7772 - val_mean_absolute_error: 41.6550
# Epoch 10/150
# 896/896 [==============================] - 0s 38us/step - loss: 516.9941 - mean_squared_error: 516.9941 - mean_absolute_error: 11.9789 - val_loss: 5013.9477 - val_mean_squared_error: 5013.9477 - val_mean_absolute_error: 41.2823
# Epoch 11/150
# 896/896 [==============================] - 0s 26us/step - loss: 508.4901 - mean_squared_error: 508.4901 - mean_absolute_error: 11.7265 - val_loss: 4972.7280 - val_mean_squared_error: 4972.7280 - val_mean_absolute_error: 40.9011
# Epoch 12/150
# 896/896 [==============================] - 0s 26us/step - loss: 498.2678 - mean_squared_error: 498.2678 - mean_absolute_error: 11.4393 - val_loss: 4933.6295 - val_mean_squared_error: 4933.6295 - val_mean_absolute_error: 40.5359
# Epoch 13/150
# 896/896 [==============================] - 0s 22us/step - loss: 489.2569 - mean_squared_error: 489.2569 - mean_absolute_error: 11.2029 - val_loss: 4892.5891 - val_mean_squared_error: 4892.5891 - val_mean_absolute_error: 40.1599
# Epoch 14/150
# 896/896 [==============================] - 0s 23us/step - loss: 477.7349 - mean_squared_error: 477.7349 - mean_absolute_error: 10.9615 - val_loss: 4852.7806 - val_mean_squared_error: 4852.7806 - val_mean_absolute_error: 39.7953
# Epoch 15/150
# 896/896 [==============================] - 0s 39us/step - loss: 468.8946 - mean_squared_error: 468.8946 - mean_absolute_error: 10.7534 - val_loss: 4812.3694 - val_mean_squared_error: 4812.3694 - val_mean_absolute_error: 39.4274
# Epoch 16/150
# 896/896 [==============================] - 0s 31us/step - loss: 459.4775 - mean_squared_error: 459.4775 - mean_absolute_error: 10.5441 - val_loss: 4771.7495 - val_mean_squared_error: 4771.7495 - val_mean_absolute_error: 39.0574
# Epoch 17/150
# 896/896 [==============================] - 0s 27us/step - loss: 451.0293 - mean_squared_error: 451.0293 - mean_absolute_error: 10.3953 - val_loss: 4733.3057 - val_mean_squared_error: 4733.3057 - val_mean_absolute_error: 38.7096
# Epoch 18/150
# 896/896 [==============================] - 0s 31us/step - loss: 443.5599 - mean_squared_error: 443.5599 - mean_absolute_error: 10.2321 - val_loss: 4693.3608 - val_mean_squared_error: 4693.3608 - val_mean_absolute_error: 38.3558
# Epoch 19/150
# 896/896 [==============================] - 0s 35us/step - loss: 435.3501 - mean_squared_error: 435.3501 - mean_absolute_error: 10.0852 - val_loss: 4653.3183 - val_mean_squared_error: 4653.3183 - val_mean_absolute_error: 38.0018
# Epoch 20/150
# 896/896 [==============================] - 0s 21us/step - loss: 425.4310 - mean_squared_error: 425.4310 - mean_absolute_error: 9.9274 - val_loss: 4616.3006 - val_mean_squared_error: 4616.3006 - val_mean_absolute_error: 37.6750
# Epoch 21/150
# 896/896 [==============================] - 0s 21us/step - loss: 417.6740 - mean_squared_error: 417.6740 - mean_absolute_error: 9.7703 - val_loss: 4578.6445 - val_mean_squared_error: 4578.6445 - val_mean_absolute_error: 37.3455
# Epoch 22/150
# 896/896 [==============================] - 0s 21us/step - loss: 411.5263 - mean_squared_error: 411.5263 - mean_absolute_error: 9.7463 - val_loss: 4541.1687 - val_mean_squared_error: 4541.1687 - val_mean_absolute_error: 37.0211
# Epoch 23/150
# 896/896 [==============================] - 0s 21us/step - loss: 405.2354 - mean_squared_error: 405.2354 - mean_absolute_error: 9.6389 - val_loss: 4506.0833 - val_mean_squared_error: 4506.0833 - val_mean_absolute_error: 36.7188
# Epoch 24/150
# 896/896 [==============================] - 0s 22us/step - loss: 398.3006 - mean_squared_error: 398.3006 - mean_absolute_error: 9.5330 - val_loss: 4469.6756 - val_mean_squared_error: 4469.6756 - val_mean_absolute_error: 36.4051
# Epoch 25/150
# 896/896 [==============================] - 0s 27us/step - loss: 388.4702 - mean_squared_error: 388.4702 - mean_absolute_error: 9.4278 - val_loss: 4435.0064 - val_mean_squared_error: 4435.0064 - val_mean_absolute_error: 36.1107
# Epoch 26/150
# 896/896 [==============================] - 0s 29us/step - loss: 384.1072 - mean_squared_error: 384.1072 - mean_absolute_error: 9.3751 - val_loss: 4399.0025 - val_mean_squared_error: 4399.0025 - val_mean_absolute_error: 35.8116
# Epoch 27/150
# 896/896 [==============================] - 0s 24us/step - loss: 378.7634 - mean_squared_error: 378.7634 - mean_absolute_error: 9.3801 - val_loss: 4365.0554 - val_mean_squared_error: 4365.0554 - val_mean_absolute_error: 35.5345
# Epoch 28/150
# 896/896 [==============================] - 0s 21us/step - loss: 372.2337 - mean_squared_error: 372.2337 - mean_absolute_error: 9.3022 - val_loss: 4332.2369 - val_mean_squared_error: 4332.2369 - val_mean_absolute_error: 35.2710
# Epoch 29/150
# 896/896 [==============================] - 0s 22us/step - loss: 367.3438 - mean_squared_error: 367.3438 - mean_absolute_error: 9.2673 - val_loss: 4299.6219 - val_mean_squared_error: 4299.6219 - val_mean_absolute_error: 35.0137
# Epoch 30/150
# 896/896 [==============================] - 0s 27us/step - loss: 361.6618 - mean_squared_error: 361.6618 - mean_absolute_error: 9.2476 - val_loss: 4269.2771 - val_mean_squared_error: 4269.2771 - val_mean_absolute_error: 34.7794
# Epoch 31/150
# 896/896 [==============================] - 0s 28us/step - loss: 365.6520 - mean_squared_error: 365.6520 - mean_absolute_error: 9.2686 - val_loss: 4238.2134 - val_mean_squared_error: 4238.2134 - val_mean_absolute_error: 34.5458
# Epoch 32/150
# 896/896 [==============================] - 0s 23us/step - loss: 355.8178 - mean_squared_error: 355.8178 - mean_absolute_error: 9.2422 - val_loss: 4207.6237 - val_mean_squared_error: 4207.6237 - val_mean_absolute_error: 34.3165
# Epoch 33/150
# 896/896 [==============================] - 0s 20us/step - loss: 349.5528 - mean_squared_error: 349.5528 - mean_absolute_error: 9.2447 - val_loss: 4179.6680 - val_mean_squared_error: 4179.6680 - val_mean_absolute_error: 34.1109
# Epoch 34/150
# 896/896 [==============================] - 0s 21us/step - loss: 346.2477 - mean_squared_error: 346.2477 - mean_absolute_error: 9.2263 - val_loss: 4151.1857 - val_mean_squared_error: 4151.1857 - val_mean_absolute_error: 33.9012
# Epoch 35/150
# 896/896 [==============================] - 0s 22us/step - loss: 342.9988 - mean_squared_error: 342.9988 - mean_absolute_error: 9.2661 - val_loss: 4123.4993 - val_mean_squared_error: 4123.4993 - val_mean_absolute_error: 33.7035
# Epoch 36/150
# 896/896 [==============================] - 0s 26us/step - loss: 342.2221 - mean_squared_error: 342.2221 - mean_absolute_error: 9.2665 - val_loss: 4097.1124 - val_mean_squared_error: 4097.1124 - val_mean_absolute_error: 33.5158
# Epoch 37/150
# 896/896 [==============================] - 0s 30us/step - loss: 338.7591 - mean_squared_error: 338.7591 - mean_absolute_error: 9.2936 - val_loss: 4073.6229 - val_mean_squared_error: 4073.6229 - val_mean_absolute_error: 33.3567
# Epoch 38/150
# 896/896 [==============================] - 0s 22us/step - loss: 332.3871 - mean_squared_error: 332.3871 - mean_absolute_error: 9.2650 - val_loss: 4047.3033 - val_mean_squared_error: 4047.3033 - val_mean_absolute_error: 33.1771
# Epoch 39/150
# 896/896 [==============================] - 0s 21us/step - loss: 329.6776 - mean_squared_error: 329.6776 - mean_absolute_error: 9.2851 - val_loss: 4023.2047 - val_mean_squared_error: 4023.2047 - val_mean_absolute_error: 33.0179
# Epoch 40/150
# 896/896 [==============================] - 0s 21us/step - loss: 328.1334 - mean_squared_error: 328.1334 - mean_absolute_error: 9.2878 - val_loss: 3999.6634 - val_mean_squared_error: 3999.6634 - val_mean_absolute_error: 32.8671
# Epoch 41/150
# 896/896 [==============================] - 0s 21us/step - loss: 323.2383 - mean_squared_error: 323.2383 - mean_absolute_error: 9.2448 - val_loss: 3977.8811 - val_mean_squared_error: 3977.8811 - val_mean_absolute_error: 32.7283
# Epoch 42/150
# 896/896 [==============================] - 0s 30us/step - loss: 319.7217 - mean_squared_error: 319.7217 - mean_absolute_error: 9.2569 - val_loss: 3954.0173 - val_mean_squared_error: 3954.0173 - val_mean_absolute_error: 32.5778
# Epoch 43/150
# 896/896 [==============================] - 0s 23us/step - loss: 326.9598 - mean_squared_error: 326.9598 - mean_absolute_error: 9.3158 - val_loss: 3934.8983 - val_mean_squared_error: 3934.8983 - val_mean_absolute_error: 32.4664
# Epoch 44/150
# 896/896 [==============================] - 0s 20us/step - loss: 317.7237 - mean_squared_error: 317.7237 - mean_absolute_error: 9.2624 - val_loss: 3916.0390 - val_mean_squared_error: 3916.0390 - val_mean_absolute_error: 32.3563
# Epoch 45/150
# 896/896 [==============================] - 0s 20us/step - loss: 317.1931 - mean_squared_error: 317.1931 - mean_absolute_error: 9.2616 - val_loss: 3897.4318 - val_mean_squared_error: 3897.4318 - val_mean_absolute_error: 32.2473
# Epoch 46/150
# 896/896 [==============================] - 0s 24us/step - loss: 312.0318 - mean_squared_error: 312.0318 - mean_absolute_error: 9.2160 - val_loss: 3881.1650 - val_mean_squared_error: 3881.1650 - val_mean_absolute_error: 32.1571
# Epoch 47/150
# 896/896 [==============================] - 0s 19us/step - loss: 318.6492 - mean_squared_error: 318.6492 - mean_absolute_error: 9.3689 - val_loss: 3860.4843 - val_mean_squared_error: 3860.4843 - val_mean_absolute_error: 32.0348
# Epoch 48/150
# 896/896 [==============================] - 0s 24us/step - loss: 310.0269 - mean_squared_error: 310.0269 - mean_absolute_error: 9.2808 - val_loss: 3846.1565 - val_mean_squared_error: 3846.1565 - val_mean_absolute_error: 31.9675
# Epoch 49/150
# 896/896 [==============================] - 0s 29us/step - loss: 304.2360 - mean_squared_error: 304.2360 - mean_absolute_error: 9.1790 - val_loss: 3829.2344 - val_mean_squared_error: 3829.2344 - val_mean_absolute_error: 31.8815
# Epoch 50/150
# 896/896 [==============================] - 0s 21us/step - loss: 305.8160 - mean_squared_error: 305.8160 - mean_absolute_error: 9.2177 - val_loss: 3812.8099 - val_mean_squared_error: 3812.8099 - val_mean_absolute_error: 31.7978
# Epoch 51/150
# 896/896 [==============================] - 0s 19us/step - loss: 300.6762 - mean_squared_error: 300.6762 - mean_absolute_error: 9.1592 - val_loss: 3798.0472 - val_mean_squared_error: 3798.0472 - val_mean_absolute_error: 31.7375
# Epoch 52/150
# 896/896 [==============================] - 0s 20us/step - loss: 305.8896 - mean_squared_error: 305.8896 - mean_absolute_error: 9.3069 - val_loss: 3781.8660 - val_mean_squared_error: 3781.8660 - val_mean_absolute_error: 31.6606
# Epoch 53/150
# 896/896 [==============================] - 0s 19us/step - loss: 297.9588 - mean_squared_error: 297.9588 - mean_absolute_error: 9.1684 - val_loss: 3766.6132 - val_mean_squared_error: 3766.6132 - val_mean_absolute_error: 31.5880
# Epoch 54/150
# 896/896 [==============================] - 0s 29us/step - loss: 298.7197 - mean_squared_error: 298.7197 - mean_absolute_error: 9.2561 - val_loss: 3749.7747 - val_mean_squared_error: 3749.7747 - val_mean_absolute_error: 31.5043
# Epoch 55/150
# 896/896 [==============================] - 0s 24us/step - loss: 298.3658 - mean_squared_error: 298.3658 - mean_absolute_error: 9.2290 - val_loss: 3736.2546 - val_mean_squared_error: 3736.2546 - val_mean_absolute_error: 31.4550
# Epoch 56/150
# 896/896 [==============================] - 0s 24us/step - loss: 298.8219 - mean_squared_error: 298.8219 - mean_absolute_error: 9.2131 - val_loss: 3721.8546 - val_mean_squared_error: 3721.8546 - val_mean_absolute_error: 31.3792
# Epoch 57/150
# 896/896 [==============================] - 0s 23us/step - loss: 291.3747 - mean_squared_error: 291.3747 - mean_absolute_error: 9.1859 - val_loss: 3707.8948 - val_mean_squared_error: 3707.8948 - val_mean_absolute_error: 31.3191
# Epoch 58/150
# 896/896 [==============================] - 0s 21us/step - loss: 291.0099 - mean_squared_error: 291.0099 - mean_absolute_error: 9.1758 - val_loss: 3695.2702 - val_mean_squared_error: 3695.2702 - val_mean_absolute_error: 31.2677
# Epoch 59/150
# 896/896 [==============================] - 0s 21us/step - loss: 291.7632 - mean_squared_error: 291.7632 - mean_absolute_error: 9.2230 - val_loss: 3680.4224 - val_mean_squared_error: 3680.4224 - val_mean_absolute_error: 31.1904
# Epoch 60/150
# 896/896 [==============================] - 0s 35us/step - loss: 293.3268 - mean_squared_error: 293.3268 - mean_absolute_error: 9.2825 - val_loss: 3667.6063 - val_mean_squared_error: 3667.6063 - val_mean_absolute_error: 31.1267
# Epoch 61/150
# 896/896 [==============================] - 0s 21us/step - loss: 286.6637 - mean_squared_error: 286.6637 - mean_absolute_error: 9.1918 - val_loss: 3655.4142 - val_mean_squared_error: 3655.4142 - val_mean_absolute_error: 31.0741
# Epoch 62/150
# 896/896 [==============================] - 0s 22us/step - loss: 294.7783 - mean_squared_error: 294.7783 - mean_absolute_error: 9.2074 - val_loss: 3646.9339 - val_mean_squared_error: 3646.9339 - val_mean_absolute_error: 31.0518
# Epoch 63/150
# 896/896 [==============================] - 0s 21us/step - loss: 287.0939 - mean_squared_error: 287.0939 - mean_absolute_error: 9.2637 - val_loss: 3633.8786 - val_mean_squared_error: 3633.8786 - val_mean_absolute_error: 30.9803
# Epoch 64/150
# 896/896 [==============================] - 0s 22us/step - loss: 286.7892 - mean_squared_error: 286.7892 - mean_absolute_error: 9.2579 - val_loss: 3621.3370 - val_mean_squared_error: 3621.3370 - val_mean_absolute_error: 30.9151
# Epoch 65/150
# 896/896 [==============================] - 0s 26us/step - loss: 280.5398 - mean_squared_error: 280.5398 - mean_absolute_error: 9.1965 - val_loss: 3612.1006 - val_mean_squared_error: 3612.1006 - val_mean_absolute_error: 30.8893
# Epoch 66/150
# 896/896 [==============================] - 0s 27us/step - loss: 289.6766 - mean_squared_error: 289.6766 - mean_absolute_error: 9.2988 - val_loss: 3602.3226 - val_mean_squared_error: 3602.3226 - val_mean_absolute_error: 30.8445
# Epoch 67/150
# 896/896 [==============================] - 0s 21us/step - loss: 286.2821 - mean_squared_error: 286.2821 - mean_absolute_error: 9.3101 - val_loss: 3590.9727 - val_mean_squared_error: 3590.9727 - val_mean_absolute_error: 30.7894
# Epoch 68/150
# 896/896 [==============================] - 0s 21us/step - loss: 280.6625 - mean_squared_error: 280.6625 - mean_absolute_error: 9.2555 - val_loss: 3586.1686 - val_mean_squared_error: 3586.1686 - val_mean_absolute_error: 30.7958
# Epoch 69/150
# 896/896 [==============================] - 0s 20us/step - loss: 280.2019 - mean_squared_error: 280.2019 - mean_absolute_error: 9.2805 - val_loss: 3574.5906 - val_mean_squared_error: 3574.5906 - val_mean_absolute_error: 30.7373
# Epoch 70/150
# 896/896 [==============================] - 0s 20us/step - loss: 282.3708 - mean_squared_error: 282.3708 - mean_absolute_error: 9.2634 - val_loss: 3565.9197 - val_mean_squared_error: 3565.9197 - val_mean_absolute_error: 30.6973
# Epoch 71/150
# 896/896 [==============================] - 0s 21us/step - loss: 283.5377 - mean_squared_error: 283.5377 - mean_absolute_error: 9.3558 - val_loss: 3554.7636 - val_mean_squared_error: 3554.7636 - val_mean_absolute_error: 30.6383
# Epoch 72/150
# 896/896 [==============================] - 0s 31us/step - loss: 285.0244 - mean_squared_error: 285.0244 - mean_absolute_error: 9.3533 - val_loss: 3552.4720 - val_mean_squared_error: 3552.4720 - val_mean_absolute_error: 30.6641
# Epoch 73/150
# 896/896 [==============================] - 0s 21us/step - loss: 277.6846 - mean_squared_error: 277.6846 - mean_absolute_error: 9.3121 - val_loss: 3541.0345 - val_mean_squared_error: 3541.0345 - val_mean_absolute_error: 30.5983
# Epoch 74/150
# 896/896 [==============================] - 0s 21us/step - loss: 279.0814 - mean_squared_error: 279.0814 - mean_absolute_error: 9.3116 - val_loss: 3531.5614 - val_mean_squared_error: 3531.5614 - val_mean_absolute_error: 30.5474
# Epoch 75/150
# 896/896 [==============================] - 0s 22us/step - loss: 278.1103 - mean_squared_error: 278.1103 - mean_absolute_error: 9.3205 - val_loss: 3523.0817 - val_mean_squared_error: 3523.0817 - val_mean_absolute_error: 30.5132
# Epoch 76/150
# 896/896 [==============================] - 0s 20us/step - loss: 275.6609 - mean_squared_error: 275.6609 - mean_absolute_error: 9.3920 - val_loss: 3515.8024 - val_mean_squared_error: 3515.8024 - val_mean_absolute_error: 30.4811
# Epoch 77/150
# 896/896 [==============================] - 0s 26us/step - loss: 274.9888 - mean_squared_error: 274.9888 - mean_absolute_error: 9.3722 - val_loss: 3511.2379 - val_mean_squared_error: 3511.2379 - val_mean_absolute_error: 30.4826
# Epoch 78/150
# 896/896 [==============================] - 0s 30us/step - loss: 272.7484 - mean_squared_error: 272.7484 - mean_absolute_error: 9.3145 - val_loss: 3505.7599 - val_mean_squared_error: 3505.7599 - val_mean_absolute_error: 30.4689
# Epoch 79/150
# 896/896 [==============================] - 0s 23us/step - loss: 273.5091 - mean_squared_error: 273.5091 - mean_absolute_error: 9.3574 - val_loss: 3496.2052 - val_mean_squared_error: 3496.2052 - val_mean_absolute_error: 30.4142
# Epoch 80/150
# 896/896 [==============================] - 0s 23us/step - loss: 279.2659 - mean_squared_error: 279.2659 - mean_absolute_error: 9.4551 - val_loss: 3481.8607 - val_mean_squared_error: 3481.8607 - val_mean_absolute_error: 30.3177
# Epoch 81/150
# 896/896 [==============================] - 0s 21us/step - loss: 281.2058 - mean_squared_error: 281.2058 - mean_absolute_error: 9.4273 - val_loss: 3481.8303 - val_mean_squared_error: 3481.8303 - val_mean_absolute_error: 30.3576
# Epoch 82/150
# 896/896 [==============================] - 0s 20us/step - loss: 274.8391 - mean_squared_error: 274.8391 - mean_absolute_error: 9.4064 - val_loss: 3474.4390 - val_mean_squared_error: 3474.4390 - val_mean_absolute_error: 30.3255
# Epoch 83/150
# 896/896 [==============================] - 0s 27us/step - loss: 271.2075 - mean_squared_error: 271.2075 - mean_absolute_error: 9.3884 - val_loss: 3470.0136 - val_mean_squared_error: 3470.0136 - val_mean_absolute_error: 30.3182
# Epoch 84/150
# 896/896 [==============================] - 0s 30us/step - loss: 272.5616 - mean_squared_error: 272.5616 - mean_absolute_error: 9.4344 - val_loss: 3461.3444 - val_mean_squared_error: 3461.3444 - val_mean_absolute_error: 30.2737
# Epoch 85/150
# 896/896 [==============================] - 0s 20us/step - loss: 271.2841 - mean_squared_error: 271.2841 - mean_absolute_error: 9.3986 - val_loss: 3457.2275 - val_mean_squared_error: 3457.2275 - val_mean_absolute_error: 30.2760
# Epoch 86/150
# 896/896 [==============================] - 0s 20us/step - loss: 271.9135 - mean_squared_error: 271.9135 - mean_absolute_error: 9.5081 - val_loss: 3449.6601 - val_mean_squared_error: 3449.6601 - val_mean_absolute_error: 30.2310
# Epoch 87/150
# 896/896 [==============================] - 0s 20us/step - loss: 274.4132 - mean_squared_error: 274.4132 - mean_absolute_error: 9.4735 - val_loss: 3444.6426 - val_mean_squared_error: 3444.6426 - val_mean_absolute_error: 30.2143
# Epoch 88/150
# 896/896 [==============================] - 0s 20us/step - loss: 273.7347 - mean_squared_error: 273.7347 - mean_absolute_error: 9.5018 - val_loss: 3438.6604 - val_mean_squared_error: 3438.6604 - val_mean_absolute_error: 30.1925
# Epoch 89/150
# 896/896 [==============================] - 0s 31us/step - loss: 275.2172 - mean_squared_error: 275.2172 - mean_absolute_error: 9.6152 - val_loss: 3437.4856 - val_mean_squared_error: 3437.4856 - val_mean_absolute_error: 30.2144
# Epoch 90/150
# 896/896 [==============================] - 0s 21us/step - loss: 276.6813 - mean_squared_error: 276.6813 - mean_absolute_error: 9.5589 - val_loss: 3430.1319 - val_mean_squared_error: 3430.1319 - val_mean_absolute_error: 30.1732
# Epoch 91/150
# 896/896 [==============================] - 0s 20us/step - loss: 293.3540 - mean_squared_error: 293.3540 - mean_absolute_error: 9.5823 - val_loss: 3430.8043 - val_mean_squared_error: 3430.8043 - val_mean_absolute_error: 30.2056
# Epoch 92/150
# 896/896 [==============================] - 0s 20us/step - loss: 268.6897 - mean_squared_error: 268.6897 - mean_absolute_error: 9.4338 - val_loss: 3427.8179 - val_mean_squared_error: 3427.8179 - val_mean_absolute_error: 30.2028
# Epoch 93/150
# 896/896 [==============================] - 0s 20us/step - loss: 270.5668 - mean_squared_error: 270.5668 - mean_absolute_error: 9.4807 - val_loss: 3418.6551 - val_mean_squared_error: 3418.6551 - val_mean_absolute_error: 30.1447
# Epoch 94/150
# 896/896 [==============================] - 0s 21us/step - loss: 270.6917 - mean_squared_error: 270.6917 - mean_absolute_error: 9.5177 - val_loss: 3412.8975 - val_mean_squared_error: 3412.8975 - val_mean_absolute_error: 30.1239
# Epoch 95/150
# 896/896 [==============================] - 0s 24us/step - loss: 278.8284 - mean_squared_error: 278.8284 - mean_absolute_error: 9.6097 - val_loss: 3406.8044 - val_mean_squared_error: 3406.8044 - val_mean_absolute_error: 30.0918
# Epoch 96/150
# 896/896 [==============================] - 0s 29us/step - loss: 267.9384 - mean_squared_error: 267.9384 - mean_absolute_error: 9.4927 - val_loss: 3406.7998 - val_mean_squared_error: 3406.7998 - val_mean_absolute_error: 30.1172
# Epoch 97/150
# 896/896 [==============================] - 0s 21us/step - loss: 267.0659 - mean_squared_error: 267.0659 - mean_absolute_error: 9.5142 - val_loss: 3402.4589 - val_mean_squared_error: 3402.4589 - val_mean_absolute_error: 30.0984
# Epoch 98/150
# 896/896 [==============================] - 0s 20us/step - loss: 267.4573 - mean_squared_error: 267.4573 - mean_absolute_error: 9.5045 - val_loss: 3398.0977 - val_mean_squared_error: 3398.0977 - val_mean_absolute_error: 30.0791
# Epoch 99/150
# 896/896 [==============================] - 0s 20us/step - loss: 272.1511 - mean_squared_error: 272.1511 - mean_absolute_error: 9.5415 - val_loss: 3394.9917 - val_mean_squared_error: 3394.9917 - val_mean_absolute_error: 30.0775
# Epoch 100/150
# 896/896 [==============================] - 0s 20us/step - loss: 268.6176 - mean_squared_error: 268.6176 - mean_absolute_error: 9.5831 - val_loss: 3391.3828 - val_mean_squared_error: 3391.3828 - val_mean_absolute_error: 30.0630
# Epoch 101/150
# 896/896 [==============================] - 0s 28us/step - loss: 266.5507 - mean_squared_error: 266.5507 - mean_absolute_error: 9.5457 - val_loss: 3381.8776 - val_mean_squared_error: 3381.8776 - val_mean_absolute_error: 29.9998
# Epoch 102/150
# 896/896 [==============================] - 0s 22us/step - loss: 266.0176 - mean_squared_error: 266.0176 - mean_absolute_error: 9.5170 - val_loss: 3376.6089 - val_mean_squared_error: 3376.6089 - val_mean_absolute_error: 29.9790
# Epoch 103/150
# 896/896 [==============================] - 0s 20us/step - loss: 268.4707 - mean_squared_error: 268.4707 - mean_absolute_error: 9.6002 - val_loss: 3376.2176 - val_mean_squared_error: 3376.2176 - val_mean_absolute_error: 30.0001
# Epoch 104/150
# 896/896 [==============================] - 0s 20us/step - loss: 268.7636 - mean_squared_error: 268.7636 - mean_absolute_error: 9.6127 - val_loss: 3375.5556 - val_mean_squared_error: 3375.5556 - val_mean_absolute_error: 30.0101
# Epoch 105/150
# 896/896 [==============================] - 0s 20us/step - loss: 267.2690 - mean_squared_error: 267.2690 - mean_absolute_error: 9.5878 - val_loss: 3367.6286 - val_mean_squared_error: 3367.6286 - val_mean_absolute_error: 29.9550
# Epoch 106/150
# 896/896 [==============================] - 0s 21us/step - loss: 262.5561 - mean_squared_error: 262.5561 - mean_absolute_error: 9.5129 - val_loss: 3366.4232 - val_mean_squared_error: 3366.4232 - val_mean_absolute_error: 29.9639
# Epoch 107/150
# 896/896 [==============================] - 0s 20us/step - loss: 274.9851 - mean_squared_error: 274.9851 - mean_absolute_error: 9.5933 - val_loss: 3366.4725 - val_mean_squared_error: 3366.4725 - val_mean_absolute_error: 29.9841
# Epoch 108/150
# 896/896 [==============================] - 0s 30us/step - loss: 269.6923 - mean_squared_error: 269.6923 - mean_absolute_error: 9.6338 - val_loss: 3365.8958 - val_mean_squared_error: 3365.8958 - val_mean_absolute_error: 29.9925
# Epoch 109/150
# 896/896 [==============================] - 0s 21us/step - loss: 266.6335 - mean_squared_error: 266.6335 - mean_absolute_error: 9.5644 - val_loss: 3358.0304 - val_mean_squared_error: 3358.0304 - val_mean_absolute_error: 29.9406
# Epoch 110/150
# 896/896 [==============================] - 0s 21us/step - loss: 262.0069 - mean_squared_error: 262.0069 - mean_absolute_error: 9.4819 - val_loss: 3352.8071 - val_mean_squared_error: 3352.8071 - val_mean_absolute_error: 29.9095
# Epoch 111/150
# 896/896 [==============================] - 0s 24us/step - loss: 260.3957 - mean_squared_error: 260.3957 - mean_absolute_error: 9.4674 - val_loss: 3351.9739 - val_mean_squared_error: 3351.9739 - val_mean_absolute_error: 29.9206
# Epoch 112/150
# 896/896 [==============================] - 0s 26us/step - loss: 265.3373 - mean_squared_error: 265.3373 - mean_absolute_error: 9.5634 - val_loss: 3350.7421 - val_mean_squared_error: 3350.7421 - val_mean_absolute_error: 29.9215
# Epoch 113/150
# 896/896 [==============================] - 0s 36us/step - loss: 265.4747 - mean_squared_error: 265.4747 - mean_absolute_error: 9.6109 - val_loss: 3347.6469 - val_mean_squared_error: 3347.6469 - val_mean_absolute_error: 29.9161
# Epoch 114/150
# 896/896 [==============================] - 0s 22us/step - loss: 267.2831 - mean_squared_error: 267.2831 - mean_absolute_error: 9.5407 - val_loss: 3341.4172 - val_mean_squared_error: 3341.4172 - val_mean_absolute_error: 29.8709
# Epoch 115/150
# 896/896 [==============================] - 0s 23us/step - loss: 262.3552 - mean_squared_error: 262.3552 - mean_absolute_error: 9.5374 - val_loss: 3343.8736 - val_mean_squared_error: 3343.8736 - val_mean_absolute_error: 29.9015
# Epoch 116/150
# 896/896 [==============================] - 0s 20us/step - loss: 267.6351 - mean_squared_error: 267.6351 - mean_absolute_error: 9.6281 - val_loss: 3337.8132 - val_mean_squared_error: 3337.8132 - val_mean_absolute_error: 29.8631
# Epoch 117/150
# 896/896 [==============================] - 0s 20us/step - loss: 261.3921 - mean_squared_error: 261.3921 - mean_absolute_error: 9.5100 - val_loss: 3336.3317 - val_mean_squared_error: 3336.3317 - val_mean_absolute_error: 29.8649
# Epoch 118/150
# 896/896 [==============================] - 0s 19us/step - loss: 263.5941 - mean_squared_error: 263.5941 - mean_absolute_error: 9.6394 - val_loss: 3335.6821 - val_mean_squared_error: 3335.6821 - val_mean_absolute_error: 29.8809
# Epoch 119/150
# 896/896 [==============================] - 0s 28us/step - loss: 264.3563 - mean_squared_error: 264.3563 - mean_absolute_error: 9.5566 - val_loss: 3329.1708 - val_mean_squared_error: 3329.1708 - val_mean_absolute_error: 29.8344
# Epoch 120/150
# 896/896 [==============================] - 0s 22us/step - loss: 264.8414 - mean_squared_error: 264.8414 - mean_absolute_error: 9.5870 - val_loss: 3323.7845 - val_mean_squared_error: 3323.7845 - val_mean_absolute_error: 29.7969
# Epoch 121/150
# 896/896 [==============================] - 0s 20us/step - loss: 263.1539 - mean_squared_error: 263.1539 - mean_absolute_error: 9.5992 - val_loss: 3323.5546 - val_mean_squared_error: 3323.5546 - val_mean_absolute_error: 29.8116
# Epoch 122/150
# 896/896 [==============================] - 0s 20us/step - loss: 260.9032 - mean_squared_error: 260.9032 - mean_absolute_error: 9.5892 - val_loss: 3322.3372 - val_mean_squared_error: 3322.3372 - val_mean_absolute_error: 29.8118
# Epoch 123/150
# 896/896 [==============================] - 0s 19us/step - loss: 259.6703 - mean_squared_error: 259.6703 - mean_absolute_error: 9.5056 - val_loss: 3321.1589 - val_mean_squared_error: 3321.1589 - val_mean_absolute_error: 29.8138
# Epoch 124/150
# 896/896 [==============================] - 0s 20us/step - loss: 269.3794 - mean_squared_error: 269.3794 - mean_absolute_error: 9.6232 - val_loss: 3317.8987 - val_mean_squared_error: 3317.8987 - val_mean_absolute_error: 29.7896
# Epoch 125/150
# 896/896 [==============================] - 0s 30us/step - loss: 260.6207 - mean_squared_error: 260.6207 - mean_absolute_error: 9.5817 - val_loss: 3315.5679 - val_mean_squared_error: 3315.5679 - val_mean_absolute_error: 29.7697
# Epoch 126/150
# 896/896 [==============================] - 0s 20us/step - loss: 266.1272 - mean_squared_error: 266.1272 - mean_absolute_error: 9.5934 - val_loss: 3318.0854 - val_mean_squared_error: 3318.0854 - val_mean_absolute_error: 29.7848
# Epoch 127/150
# 896/896 [==============================] - 0s 19us/step - loss: 265.8293 - mean_squared_error: 265.8293 - mean_absolute_error: 9.4864 - val_loss: 3310.6085 - val_mean_squared_error: 3310.6085 - val_mean_absolute_error: 29.6813
# Epoch 128/150
# 896/896 [==============================] - 0s 19us/step - loss: 261.4609 - mean_squared_error: 261.4609 - mean_absolute_error: 9.4563 - val_loss: 3307.3867 - val_mean_squared_error: 3307.3867 - val_mean_absolute_error: 29.6050
# Epoch 129/150
# 896/896 [==============================] - 0s 19us/step - loss: 256.7444 - mean_squared_error: 256.7444 - mean_absolute_error: 9.3089 - val_loss: 3309.5095 - val_mean_squared_error: 3309.5095 - val_mean_absolute_error: 29.5761
# Epoch 130/150
# 896/896 [==============================] - 0s 20us/step - loss: 259.6455 - mean_squared_error: 259.6455 - mean_absolute_error: 9.3456 - val_loss: 3303.6771 - val_mean_squared_error: 3303.6771 - val_mean_absolute_error: 29.4822
# Epoch 131/150
# 896/896 [==============================] - 0s 21us/step - loss: 268.7468 - mean_squared_error: 268.7468 - mean_absolute_error: 9.3073 - val_loss: 3308.0658 - val_mean_squared_error: 3308.0658 - val_mean_absolute_error: 29.4927
# Epoch 132/150
# 896/896 [==============================] - 0s 30us/step - loss: 259.6959 - mean_squared_error: 259.6959 - mean_absolute_error: 9.2910 - val_loss: 3308.7752 - val_mean_squared_error: 3308.7752 - val_mean_absolute_error: 29.4953
# Epoch 133/150
# 896/896 [==============================] - 0s 22us/step - loss: 259.0231 - mean_squared_error: 259.0231 - mean_absolute_error: 9.3103 - val_loss: 3305.7295 - val_mean_squared_error: 3305.7295 - val_mean_absolute_error: 29.4453
# Epoch 134/150
# 896/896 [==============================] - 0s 20us/step - loss: 257.7672 - mean_squared_error: 257.7672 - mean_absolute_error: 9.2474 - val_loss: 3296.8447 - val_mean_squared_error: 3296.8447 - val_mean_absolute_error: 29.3699
# Epoch 135/150
# 896/896 [==============================] - 0s 19us/step - loss: 254.8864 - mean_squared_error: 254.8864 - mean_absolute_error: 9.1690 - val_loss: 3301.7302 - val_mean_squared_error: 3301.7302 - val_mean_absolute_error: 29.4354
# Epoch 136/150
# 896/896 [==============================] - 0s 20us/step - loss: 260.2737 - mean_squared_error: 260.2737 - mean_absolute_error: 9.2408 - val_loss: 3300.3236 - val_mean_squared_error: 3300.3236 - val_mean_absolute_error: 29.4169
# Epoch 137/150
# 896/896 [==============================] - 0s 27us/step - loss: 260.8780 - mean_squared_error: 260.8780 - mean_absolute_error: 9.2657 - val_loss: 3294.3397 - val_mean_squared_error: 3294.3397 - val_mean_absolute_error: 29.3654
# Epoch 138/150
# 896/896 [==============================] - 0s 27us/step - loss: 266.4280 - mean_squared_error: 266.4280 - mean_absolute_error: 9.3676 - val_loss: 3293.3170 - val_mean_squared_error: 3293.3170 - val_mean_absolute_error: 29.3486
# Epoch 139/150
# 896/896 [==============================] - 0s 20us/step - loss: 253.9261 - mean_squared_error: 253.9261 - mean_absolute_error: 9.1227 - val_loss: 3298.5225 - val_mean_squared_error: 3298.5225 - val_mean_absolute_error: 29.4099
# Epoch 140/150
# 896/896 [==============================] - 0s 20us/step - loss: 255.1497 - mean_squared_error: 255.1497 - mean_absolute_error: 9.0950 - val_loss: 3294.0321 - val_mean_squared_error: 3294.0321 - val_mean_absolute_error: 29.3698
# Epoch 141/150
# 896/896 [==============================] - 0s 19us/step - loss: 252.3251 - mean_squared_error: 252.3251 - mean_absolute_error: 9.0422 - val_loss: 3292.4056 - val_mean_squared_error: 3292.4056 - val_mean_absolute_error: 29.3593
# Epoch 142/150
# 896/896 [==============================] - 0s 19us/step - loss: 252.1604 - mean_squared_error: 252.1604 - mean_absolute_error: 9.0569 - val_loss: 3291.3311 - val_mean_squared_error: 3291.3311 - val_mean_absolute_error: 29.3502
# Epoch 143/150
# 896/896 [==============================] - 0s 27us/step - loss: 251.0413 - mean_squared_error: 251.0413 - mean_absolute_error: 9.0106 - val_loss: 3285.2181 - val_mean_squared_error: 3285.2181 - val_mean_absolute_error: 29.3043
# Epoch 144/150
# 896/896 [==============================] - 0s 33us/step - loss: 258.9017 - mean_squared_error: 258.9017 - mean_absolute_error: 9.0733 - val_loss: 3284.9643 - val_mean_squared_error: 3284.9643 - val_mean_absolute_error: 29.3240
# Epoch 145/150
# 896/896 [==============================] - 0s 22us/step - loss: 252.4000 - mean_squared_error: 252.4000 - mean_absolute_error: 8.9927 - val_loss: 3288.6775 - val_mean_squared_error: 3288.6775 - val_mean_absolute_error: 29.3652
# Epoch 146/150
# 896/896 [==============================] - 0s 21us/step - loss: 249.9850 - mean_squared_error: 249.9850 - mean_absolute_error: 8.9405 - val_loss: 3281.9342 - val_mean_squared_error: 3281.9342 - val_mean_absolute_error: 29.3111
# Epoch 147/150
# 896/896 [==============================] - 0s 21us/step - loss: 253.6456 - mean_squared_error: 253.6456 - mean_absolute_error: 8.9974 - val_loss: 3278.9094 - val_mean_squared_error: 3278.9094 - val_mean_absolute_error: 29.2946
# Epoch 148/150
# 896/896 [==============================] - 0s 20us/step - loss: 252.2757 - mean_squared_error: 252.2757 - mean_absolute_error: 8.9831 - val_loss: 3276.3101 - val_mean_squared_error: 3276.3101 - val_mean_absolute_error: 29.2883
# Epoch 149/150
# 896/896 [==============================] - 0s 29us/step - loss: 252.9518 - mean_squared_error: 252.9518 - mean_absolute_error: 8.9799 - val_loss: 3268.8507 - val_mean_squared_error: 3268.8507 - val_mean_absolute_error: 29.2251
# Epoch 150/150
# 896/896 [==============================] - 0s 22us/step - loss: 250.5315 - mean_squared_error: 250.5315 - mean_absolute_error: 8.9457 - val_loss: 3267.5195 - val_mean_squared_error: 3267.5195 - val_mean_absolute_error: 29.2263

# %%
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'loss', 'mean_squared_error', 'mean_absolute_error'])

# %% [markdown]
# ## Train, Valid, Test set으로 나눠서 예측하고 지표(RMSE,MAE,CORR,R2) 측정

# %%
y_pred_train = model.predict(X_train)
y_pred_valid= model.predict(X_valid)
y_pred_test = model.predict(X_test)

# %%
RMSE_2003_2011 = mean_squared_error(y_train,y_pred_train)**0.5
MAE_2003_2011 = mean_absolute_error(y_train,y_pred_train)
RMSE_2012_2014 = mean_squared_error(y_valid,y_pred_valid)**0.5
MAE_2012_2014 = mean_absolute_error(y_valid,y_pred_valid)
RMSE_2015_2017 = mean_squared_error(y_test,y_pred_test)**0.5
MAE_2015_2017 = mean_absolute_error(y_test,y_pred_test)

y_train_corr = np.corrcoef(y_train,y_pred_train[:,0])
y_valid_corr = np.corrcoef(y_valid,y_pred_valid[:,0])
y_test_corr = np.corrcoef(y_test,y_pred_test[:,0])

# %% [markdown]
# ## 결과 그래프 시각화

# %%
#df_sigan = df
X_train_sigan = df[2:1123]
X_valid_sigan = df[1123:1496]
X_test_sigan = df[1496:]

X_train_sigan.kma_ymh = X_train_sigan.kma_year.astype(str) + "-" +X_train_sigan.kma_month.astype(str) +"-"+ X_train_sigan.kma_date.astype(str)
X_valid_sigan.kma_ymh = X_valid_sigan.kma_year.astype(str) + "-" +X_valid_sigan.kma_month.astype(str) +"-"+ X_valid_sigan.kma_date.astype(str)
X_test_sigan.kma_ymh = X_test_sigan.kma_year.astype(str) + "-" +X_test_sigan.kma_month.astype(str) +"-"+ X_test_sigan.kma_date.astype(str)
# Out:
# C:\Users\KHJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# C:\Users\KHJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   import sys
# C:\Users\KHJ\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
#plt.subplot(311)
plt.figure(figsize=(30, 7))
plt.plot( X_train_sigan.kma_ymh,y_train, 'r--',label='실제값')
plt.plot( X_train_sigan.kma_ymh,y_pred_train, 'b',label='예측값')
plt.xticks(np.arange(0,1120,100))
plt.legend(loc=2)
plt.show()
print("Train SET RMSE : ",RMSE_2003_2011)
print("Train SET MAE : ",MAE_2003_2011)
print("Correlation Coefficient")
print(y_train_corr)
print('Training r2_score: {}'.format(r2_score(y_train, y_pred_train)))

print("Train")

plt.figure(figsize=(30, 7))
plt.plot( X_valid_sigan.kma_ymh,y_valid, 'r--',label='실제값')
plt.plot( X_valid_sigan.kma_ymh,y_pred_valid, 'b',label='예측값')
plt.xticks(np.arange(0,380,30))
plt.legend(loc=2)
plt.show()
print("Validation SET RMSE : ",RMSE_2012_2014)
print("Validation SET MAE : ",MAE_2012_2014)
print("Correlation Coefficient")
print(y_valid_corr)
print('Validation r2_score: {}'.format(r2_score(y_valid, y_pred_valid)))

print("Valid")

#plt.subplot(312)
plt.figure(figsize=(30, 7))
plt.plot( X_test_sigan.kma_ymh,y_test, 'r--',label='실제값')
plt.plot( X_test_sigan.kma_ymh,y_pred_test, 'b',label='예측값')
plt.xticks(np.arange(0,380,30))
plt.legend(loc=2)
plt.show()


print("Test SET RMSE : ",RMSE_2015_2017)
print("Test SET MAE : ",MAE_2015_2017)
print("Correlation Coefficient")
print(y_test_corr)
print('Test r2_score: {}'.format(r2_score(y_test, y_pred_test)))
print("Test")
# Out:
# Train SET RMSE :  29.235110220279143
# Train SET MAE :  12.91353858288886
# Correlation Coefficient
# [[1.         0.59451472]
#  [0.59451472 1.        ]]
# Training r2_score: 0.2593009612017795
# Train
# Validation SET RMSE :  50.511052089877886
# Validation SET MAE :  35.1608641564886
# Correlation Coefficient
# [[1.        0.7639576]
#  [0.7639576 1.       ]]
# Validation r2_score: -0.26577540060166926
# Valid
# Test SET RMSE :  29.331592416850153
# Test SET MAE :  18.001925711823816
# Correlation Coefficient
# [[1.         0.73894815]
#  [0.73894815 1.        ]]
# Test r2_score: 0.10772647022271209
# Test

# %% [markdown]
# ## 분석 후 모델 저장

# %%
model.save('cold_model.h5')

# %%
# 0. 사용할 패키지 불러오기
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
from numpy import argmax
# 2. 모델 불러오기
from keras.models import load_model
model2 = load_model('cold_model.h5')

# %%
y_pred_train = model2.predict(X_train)
y_pred_valid= model2.predict(X_valid)
y_pred_test = model2.predict(X_test)

# %%
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (14,4)
